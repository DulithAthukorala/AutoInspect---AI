# %%
from ultralytics import YOLO


model = YOLO("runs/segment/train/weights/best.pt")  
results = model("data/CarDD_COCO/val2017/000013.jpg")
objects = results[0]


print(results)  # print results object
# Out:
# image 1/1 c:\Users\user\Desktop\AutoInspect AI\data\CarDD_COCO\val2017\000013.jpg: 448x640 1 tire flat, 64.6ms
# Speed: 1.8ms preprocess, 64.6ms inference, 16.6ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: ultralytics.engine.results.Masks object
# names: {0: 'dent', 1: 'scratch', 2: 'crack', 3: 'glass shatter', 4: 'lamp broken', 5: 'tire flat'}
# obb: None
# orig_img: array([[[ 20,  31,  29],
#         [ 15,  28,  26],
#         [  8,  16,  15],
#         ...,
#         [ 43,  49,  56],
#         [ 45,  51,  58],
#         [ 49,  52,  60]],
#
#        [[ 18,  27,  24],
#         [ 12,  23,  20],
#         [  8,  16,  15],
#         ...,
#         [ 40,  43,  51],
#         [ 41,  45,  50],
#         [ 41,  46,  55]],
#
#        [[ 18,  25,  22],
#         [ 20,  28,  27],
#         [ 18,  26,  25],
#         ...,
#         [ 40,  49,  53],
# ...

# %%
objects.boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([5.], device='cuda:0')
# conf: tensor([0.9368], device='cuda:0')
# data: tensor([[320.0990, 266.1308, 550.9495, 489.7469,   0.9368,   5.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (685, 1000)
# shape: torch.Size([1, 6])
# xywh: tensor([[435.5242, 377.9389, 230.8504, 223.6161]], device='cuda:0')
# xywhn: tensor([[0.4355, 0.5517, 0.2309, 0.3264]], device='cuda:0')
# xyxy: tensor([[320.0990, 266.1308, 550.9495, 489.7469]], device='cuda:0')
# xyxyn: tensor([[0.3201, 0.3885, 0.5509, 0.7150]], device='cuda:0')

# %%
objects.orig_img
# Out:
# array([[[ 20,  31,  29],
#         [ 15,  28,  26],
#         [  8,  16,  15],
#         ...,
#         [ 43,  49,  56],
#         [ 45,  51,  58],
#         [ 49,  52,  60]],
#
#        [[ 18,  27,  24],
#         [ 12,  23,  20],
#         [  8,  16,  15],
#         ...,
#         [ 40,  43,  51],
#         [ 41,  45,  50],
#         [ 41,  46,  55]],
#
#        [[ 18,  25,  22],
#         [ 20,  28,  27],
#         [ 18,  26,  25],
#         ...,
#         [ 40,  49,  53],
#         [ 31,  35,  40],
#         [ 32,  36,  41]],
#
#        ...,
#
#        [[117, 128, 136],
#         [111, 127, 134],
#         [109, 116, 125],
#         ...,
#         [101, 107, 118],
#         [112, 123, 131],
#         [110, 121, 129]],
#
#        [[120, 128, 135],
#         [114, 121, 130],
#         [115, 121, 128],
#         ...,
#         [ 89,  90, 104],
#         [108, 118, 128],
#         [111, 126, 135]],
#
#        [[119, 128, 132],
#         [109, 118, 127],
#         [111, 117, 128],
# ...

# %%
objects.orig_shape
# Out:
# (685, 1000)

# %%
masks = objects.masks.data.cpu().numpy()  # height, width

# %%
masks.shape
# Out:
# (1, 448, 640)

# %%
cls_id = objects.boxes.cls.cpu().numpy()
names = objects.names

# %%
names[int(cls_id)]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21524\1781474627.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   names[int(cls_id)]
# 'tire flat'
